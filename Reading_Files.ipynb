# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data.json',
#  'Reading_Files.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Testing.ipynb']

# %%
import pandas

# reading a csv file
data_csv = pandas.read_csv("supermarkets.csv")
data_csv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# reading a txt file which is comma separated
data_txt =  pandas.read_csv("supermarkets-commas.txt")
data_txt
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# reading a semi colon separated text file
data_txt = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
data_txt
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# reading an excel file
data_excel = pandas.read_excel("supermarkets.xlsx", sheet_name = 0)
data_excel
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
# reading a json file
data_json = pandas.read_json("supermarkets.json")
data_json
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# reading a csv file without a header
data_csv = pandas.read_csv("supermarkets.csv", header = None)
data_csv
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
# adding column names to the DataFrame
data_csv.columns = ["ID","Address","City","State","Country","Name","Employees"]
data_csv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# computing mean, sum, max, min of columns in a DataFrame

print("Mean = ", data_txt.mean()["Employees"])
print("Total employees = ", data_txt.sum()["Employees"])
print("Minimum number of employees : ", data_txt.min()["Employees"])
print("Maximum number of employees : ", data_txt.max()["Employees"])
# Out:
# Mean =  15.0
# Total employees =  90
# Minimum number of employees :  8
# Maximum number of employees :  25

# %%
# setting index temporarily to a dataframe
data_csv.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
data_csv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# making a new data frame to retain the index 
data_csv_new = data_csv.set_index("ID")
data_csv_new
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
data_csv_new.set_index("Name", inplace = True, drop = False)
data_csv_new
# Out:
#                      Address           City             State Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
# Madeira          Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
data_csv = pandas.read_csv("supermarkets.csv", header = None)
data_csv.columns = ["ID","Address","City","State","Country","Name","Employees"]
data_csv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data_csv.set_index("ID", inplace=True, drop = False)

# %%
data_csv
# Out:
#     ID          Address           City             State Country         Name  \
# ID
# 1    1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3    3      332 Hill St  San Francisco  California 94114     USA  Super River
# 4    4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5    5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
import pandas
data_csv = pandas.read_csv("supermarkets.csv")
data_csv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data_csv.set_index("ID",inplace=True)

# %%
data_csv
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
# indexing and slicing

# indexing by name (the last index is incuded)
data_csv.loc["2":"4","Address":"Country"]
# Out:
#            Address           City             State Country
# ID
# 2   735 Dolores St  San Francisco          CA 94119     USA
# 3      332 Hill St  San Francisco  California 94114     USA
# 4     3995 23rd St  San Francisco          CA 94114     USA

# %%
data_csv.loc["4":"5","Name":"Employees"]
# Out:
#           Name  Employees
# ID
# 4   Ben's Shop         10
# 5      Sanchez         12

# %%
list(data_csv.loc[:,"Name"])
# Out:
# ['Madeira',
#  'Bready Shop',
#  'Super River',
#  "Ben's Shop",
#  'Sanchez',
#  'Richvalley']

# %%
# indexing by position (exclusive of last index)
data_csv.iloc[1:4, 0:4]
# Out:
#            Address           City             State Country
# ID
# 2   735 Dolores St  San Francisco          CA 94119     USA
# 3      332 Hill St  San Francisco  California 94114     USA
# 4     3995 23rd St  San Francisco          CA 94114     USA

# %%
data_csv.iloc[3,4]
# Out:
# "Ben's Shop"

# %%
data_csv.iloc[:3,:4]
# Out:
#            Address           City             State Country
# ID
# 1     3666 21st St  San Francisco          CA 94114     USA
# 2   735 Dolores St  San Francisco          CA 94119     USA
# 3      332 Hill St  San Francisco  California 94114     USA

# %%
# to get a single value by indexing
data_csv.iloc[2,2]
# Out:
# 'California 94114'

# %%
# deleting a single row 
data_csv.drop(4,0)
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 5          12
# 6          20

# %%
data_csv.columns
# Out:
# Index(['Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
data_csv.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name='ID')

# %%
help(data_csv.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise') method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Whether to drop labels from the index (0 or 'index') or
#         columns (1 or 'columns').
#     index : single label or list-like
#         Alternative to specifying axis (``labels, axis=0``
#         is equivalent to ``index=labels``).
#     columns : single label or list-like
# ...

# %%
# deleting a single column
data_csv.drop("Country", 1)
# Out:
#             Address           City             State         Name  Employees  \
# ID
# 1      3666 21st St  San Francisco          CA 94114      Madeira          8
# 2    735 Dolores St  San Francisco          CA 94119  Bready Shop         15
# 3       332 Hill St  San Francisco  California 94114  Super River         25
# 4      3995 23rd St  San Francisco          CA 94114   Ben's Shop         10
# 5   1056 Sanchez St  San Francisco        California      Sanchez         12
# 6   551 Alvarado St  San Francisco          CA 94114   Richvalley         20
#
#         Continent
# ID
# 1   North America
# 2   North America
# 3   North America
# 4   North America
# 5   North America
# 6   North America

# %%
# deleting a single row
data_csv.drop(1,0)
# Out:
#             Address           City             State Country         Name  \
# ID
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
#deleting multiple rows by slicing
data_csv.drop(data_csv.index[3:5],0)
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 6          20  North America

# %%
# delete multiple columns
data_csv.drop(data_csv.columns[0:4],1)
# Out:
#            Name  Employees      Continent
# ID
# 1       Madeira          8  North America
# 2   Bready Shop         15  North America
# 3   Super River         25  North America
# 4    Ben's Shop         10  North America
# 5       Sanchez         12  North America
# 6    Richvalley         20  North America

# %%
# shape of a data frame gives a tuple of the number of rows and columns in it
data_csv.shape
# Out:
# (6, 6)

# %%
#adding a columnn to the data frame
import pandas
data_csv = pandas.read_csv("supermarkets.csv")
data_csv.set_index("ID", inplace=True)
data_csv["Continent"] = data_csv.shape[0]*["North America"]
data_csv
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
# indexing and slicing

data_csv["City"] #indexing one columns only  - this will return an object coz no square brackets around City
# Out:
# 1    San Francisco
# 2    San Francisco
# 3    San Francisco
# 4    San Francisco
# 5    San Francisco
# 6    San Francisco
# Name: City, dtype: object

# %%
data_csv[["City"]] # indexing columns with square brackets - this will return a data frame
# Out:
#             City
# 1  San Francisco
# 2  San Francisco
# 3  San Francisco
# 4  San Francisco
# 5  San Francisco
# 6  San Francisco

# %%
data_csv[["City","State","Country"]] #indexing multiple columns
# Out:
#              City             State Country
# ID
# 1   San Francisco          CA 94114     USA
# 2   San Francisco          CA 94119     USA
# 3   San Francisco  California 94114     USA
# 4   San Francisco          CA 94114     USA
# 5   San Francisco        California     USA
# 6   San Francisco          CA 94114     USA

# %%
data_csv.index = ["1","2","3","4","5","6"]

# %%
data_csv[3:5] # for rows, ony integer index based slicing can be done (even if the rows have labels)
# Out:
#            Address           City       State Country        Name  Employees  \
# 4     3995 23rd St  San Francisco    CA 94114     USA  Ben's Shop         10
# 5  1056 Sanchez St  San Francisco  California     USA     Sanchez         12
#
#        Continent
# 4  North America
# 5  North America

# %%
data_csv.loc[:,"Country"]
# Out:
# ID
# 1    USA
# 2    USA
# 3    USA
# 4    USA
# 5    USA
# 6    USA
# Name: Country, dtype: object

# %%
data_csv.loc[:,["City","State"]]
# Out:
#              City             State
# ID
# 1   San Francisco          CA 94114
# 2   San Francisco          CA 94119
# 3   San Francisco  California 94114
# 4   San Francisco          CA 94114
# 5   San Francisco        California
# 6   San Francisco          CA 94114

# %%
data_csv.loc[:, "Address": "Country"]
# Out:
#             Address           City             State Country
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA
# 2    735 Dolores St  San Francisco          CA 94119     USA
# 3       332 Hill St  San Francisco  California 94114     USA
# 4      3995 23rd St  San Francisco          CA 94114     USA
# 5   1056 Sanchez St  San Francisco        California     USA
# 6   551 Alvarado St  San Francisco          CA 94114     USA

# %%
data_csv.index = ["1","2","3","4","5","6"]

# %%
data_csv.loc["1"]
# Out:
# Address       3666 21st St
# City         San Francisco
# State             CA 94114
# Country                USA
# Name               Madeira
# Employees                8
# Continent    North America
# Name: 1, dtype: object

# %%
data_csv.loc[["1"]]
# Out:
#         Address           City     State Country     Name  Employees  \
# 1  3666 21st St  San Francisco  CA 94114     USA  Madeira          8
#
#        Continent
# 1  North America

# %%
data_csv.loc[["1","2"]]
# Out:
#           Address           City     State Country         Name  Employees  \
# 1    3666 21st St  San Francisco  CA 94114     USA      Madeira          8
# 2  735 Dolores St  San Francisco  CA 94119     USA  Bready Shop         15
#
#        Continent
# 1  North America
# 2  North America

# %%
data_csv.loc["1":"4"]
# Out:
#           Address           City             State Country         Name  \
# 1    3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2  735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3     332 Hill St  San Francisco  California 94114     USA  Super River
# 4    3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
#
#    Employees      Continent
# 1          8  North America
# 2         15  North America
# 3         25  North America
# 4         10  North America

# %%
data_csv.loc["1":"3",:"Name"]
# Out:
#           Address           City             State Country         Name
# 1    3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2  735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3     332 Hill St  San Francisco  California 94114     USA  Super River

# %%
data_csv.iloc[:2,4] # slice of the first two rows and 4th col will be returned as an object with label Name
# Out:
# 1        Madeira
# 2    Bready Shop
# Name: Name, dtype: object

# %%
# to return as a data frame put the column position in []
data_csv.iloc[:2,[4]]
# Out:
#           Name
# 1      Madeira
# 2  Bready Shop

# %%
# indexing a single cell
data_csv.iloc[2,2] # this will return the cell value as string
# Out:
# 'California 94114'

# %%
data_csv.iloc[2,[2]] # this will return the cell value as an object
# Out:
# State    California 94114
# Name: 3, dtype: object

# %%
data_csv.iloc[[2],[2]] # this will return the cell value as a dataframe
# Out:
#               State
# 3  California 94114

# %%
# pick a slice of both rows and columns using iloc
data_csv.iloc[:2,:2]
# Out:
#           Address           City
# 1    3666 21st St  San Francisco
# 2  735 Dolores St  San Francisco

# %%
data_csv.iloc[[4],:3]
# Out:
#            Address           City       State
# 5  1056 Sanchez St  San Francisco  California

# %%
# deleting rows and columns
# the axis of the drop function has a value 0 for rows and 1 for columns
data_csv.index = [1,2,3,4,5,6]
data_csv.drop(3,0) # index based dropping of rows (works ony when rows have integer indices)
# Out:
#            Address           City       State Country         Name  Employees  \
# 1     3666 21st St  San Francisco    CA 94114     USA      Madeira          8
# 2   735 Dolores St  San Francisco    CA 94119     USA  Bready Shop         15
# 4     3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop         10
# 5  1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 6  551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20
#
#        Continent
# 1  North America
# 2  North America
# 4  North America
# 5  North America
# 6  North America

# %%
data_csv.index = ["1","2","3","4","5","6"]

# %%
data_csv
# Out:
#            Address           City             State Country         Name  \
# 1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3      332 Hill St  San Francisco  California 94114     USA  Super River
# 4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 1          8  North America
# 2         15  North America
# 3         25  North America
# 4         10  North America
# 5         12  North America
# 6         20  North America

# %%
data_csv.drop("4",0) # deletes the 4th row due to label based indexing
# Out:
#            Address           City             State Country         Name  \
# 1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3      332 Hill St  San Francisco  California 94114     USA  Super River
# 5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 1          8  North America
# 2         15  North America
# 3         25  North America
# 5         12  North America
# 6         20  North America

# %%
# to use index based dropping on labeled rows
data_csv.drop(data_csv.index[3],0) # this should delete the fourth row based on integer index 3
# Out:
#            Address           City             State Country         Name  \
# 1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3      332 Hill St  San Francisco  California 94114     USA  Super River
# 5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 1          8  North America
# 2         15  North America
# 3         25  North America
# 5         12  North America
# 6         20  North America

# %%
#dropping columns with integer based indexes
data_csv.drop(data_csv.columns[2],1) #cant use integer column indices directly coz they have labels. So use the columns object of data_csv
# Out:
#            Address           City Country         Name  Employees  \
# 1     3666 21st St  San Francisco     USA      Madeira          8
# 2   735 Dolores St  San Francisco     USA  Bready Shop         15
# 3      332 Hill St  San Francisco     USA  Super River         25
# 4     3995 23rd St  San Francisco     USA   Ben's Shop         10
# 5  1056 Sanchez St  San Francisco     USA      Sanchez         12
# 6  551 Alvarado St  San Francisco     USA   Richvalley         20
#
#        Continent
# 1  North America
# 2  North America
# 3  North America
# 4  North America
# 5  North America
# 6  North America

# %%
data_csv.drop("Country",1) # should drop country column
# Out:
#            Address           City             State         Name  Employees  \
# 1     3666 21st St  San Francisco          CA 94114      Madeira          8
# 2   735 Dolores St  San Francisco          CA 94119  Bready Shop         15
# 3      332 Hill St  San Francisco  California 94114  Super River         25
# 4     3995 23rd St  San Francisco          CA 94114   Ben's Shop         10
# 5  1056 Sanchez St  San Francisco        California      Sanchez         12
# 6  551 Alvarado St  San Francisco          CA 94114   Richvalley         20
#
#        Continent
# 1  North America
# 2  North America
# 3  North America
# 4  North America
# 5  North America
# 6  North America

# %%
#dropping slices of rows with integer indices only
data_csv.drop(data_csv.index[:3],0)
# Out:
#            Address           City       State Country        Name  Employees  \
# 4     3995 23rd St  San Francisco    CA 94114     USA  Ben's Shop         10
# 5  1056 Sanchez St  San Francisco  California     USA     Sanchez         12
# 6  551 Alvarado St  San Francisco    CA 94114     USA  Richvalley         20
#
#        Continent
# 4  North America
# 5  North America
# 6  North America

# %%
# dropping of slices of columns - index based only
data_csv.drop(data_csv.columns[4:6],1) # should drop the Name and Employees columns
# Out:
#            Address           City             State Country      Continent
# 1     3666 21st St  San Francisco          CA 94114     USA  North America
# 2   735 Dolores St  San Francisco          CA 94119     USA  North America
# 3      332 Hill St  San Francisco  California 94114     USA  North America
# 4     3995 23rd St  San Francisco          CA 94114     USA  North America
# 5  1056 Sanchez St  San Francisco        California     USA  North America
# 6  551 Alvarado St  San Francisco          CA 94114     USA  North America

# %%
import pandas
data_csv = pandas.read_csv("supermarkets.csv", index_col=0)
data_csv
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
data_csv.drop(2,0) #rows can be dropped by integer indices only here with axis 0
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 3          25
# 4          10
# 5          12
# 6          20

# %%
data_csv.drop("Country",1) # columns can be dropped with labels only here and with axis 1
# Out:
#             Address           City             State         Name  Employees
# ID
# 1      3666 21st St  San Francisco          CA 94114      Madeira          8
# 2    735 Dolores St  San Francisco          CA 94119  Bready Shop         15
# 3       332 Hill St  San Francisco  California 94114  Super River         25
# 4      3995 23rd St  San Francisco          CA 94114   Ben's Shop         10
# 5   1056 Sanchez St  San Francisco        California      Sanchez         12
# 6   551 Alvarado St  San Francisco          CA 94114   Richvalley         20

# %%
# dropping columns by index
data_csv.drop(data_csv.columns[3],1)
# Out:
#             Address           City             State         Name  Employees
# ID
# 1      3666 21st St  San Francisco          CA 94114      Madeira          8
# 2    735 Dolores St  San Francisco          CA 94119  Bready Shop         15
# 3       332 Hill St  San Francisco  California 94114  Super River         25
# 4      3995 23rd St  San Francisco          CA 94114   Ben's Shop         10
# 5   1056 Sanchez St  San Francisco        California      Sanchez         12
# 6   551 Alvarado St  San Francisco          CA 94114   Richvalley         20

# %%
# dropping rows by index object
data_csv.drop(data_csv.index[1],0) # no label based dropping for rows
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 3          25
# 4          10
# 5          12
# 6          20

# %%
 # dropping slices of rows and columns can be done with index and columns objects only
    
data_csv.drop(data_csv.index[:3],0)
data_csv.drop(data_csv.columns[4:],1)
# Out:
#             Address           City             State Country
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA
# 2    735 Dolores St  San Francisco          CA 94119     USA
# 3       332 Hill St  San Francisco  California 94114     USA
# 4      3995 23rd St  San Francisco          CA 94114     USA
# 5   1056 Sanchez St  San Francisco        California     USA
# 6   551 Alvarado St  San Francisco          CA 94114     USA

# %%
data_csv.shape
# Out:
# (6, 6)

# %%
# adding more columns
data_csv["Continent"] = data_csv.shape[0] * ["North America"]
data_csv
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
# updating a column
data_csv["State"] = "CA"
data_csv["Zip"] = data_csv.shape[0] * ["94114"]
data_csv
# Out:
#             Address           City State Country         Name  Employees  \
# ID
# 1      3666 21st St  San Francisco    CA     USA      Madeira          8
# 2    735 Dolores St  San Francisco    CA     USA  Bready Shop         15
# 3       332 Hill St  San Francisco    CA     USA  Super River         25
# 4      3995 23rd St  San Francisco    CA     USA   Ben's Shop         10
# 5   1056 Sanchez St  San Francisco    CA     USA      Sanchez         12
# 6   551 Alvarado St  San Francisco    CA     USA   Richvalley         20
#
#         Continent    Zip
# ID
# 1   North America  94114
# 2   North America  94114
# 3   North America  94114
# 4   North America  94114
# 5   North America  94114
# 6   North America  94114

# %%
type(data_csv)
# Out:
# pandas.core.frame.DataFrame

# %%
# transpose of a dataframe
data_csv_t = data_csv.T
data_csv_t
# Out:
# ID                     1               2              3              4  \
# Address     3666 21st St  735 Dolores St    332 Hill St   3995 23rd St
# City       San Francisco   San Francisco  San Francisco  San Francisco
# State                 CA              CA             CA             CA
# Country              USA             USA            USA            USA
# Name             Madeira     Bready Shop    Super River     Ben's Shop
# Employees              8              15             25             10
# Continent  North America   North America  North America  North America
# Zip                94114           94114          94114          94114
#
# ID                       5                6
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# State                   CA               CA
# Country                USA              USA
# Name               Sanchez       Richvalley
# Employees               12               20
# ...

# %%
data_csv = pandas.read_excel("supermarkets.xlsx", sheet_name=0)
data_csv
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
data_csv.loc[[2,3],["Supermarket Name"]] # indexing rows with integer indices using loc when rows don't have labels
# Out:
#   Supermarket Name
# 2      Super River
# 3       Ben's Shop

# %%
data_csv = pandas.read_csv("supermarkets.csv", header = None)
data_csv
# Out:
#     0                1              2                 3        4            5  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#            6
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
# drop the first row of data_csv
data_csv = data_csv.drop(0,0)
data_csv
# Out:
#    0                1              2                 3    4            5   6
# 1  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 2  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 3  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 4  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 5  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 6  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
# how to reference columns with loc object when they don't have labels
data_csv.loc[:,[5,6]]
# Out:
#              5   6
# 1      Madeira   8
# 2  Bready Shop  15
# 3  Super River  25
# 4   Ben's Shop  10
# 5      Sanchez  12
# 6   Richvalley  20

# %%
data_csv.columns = ["ID", "Address", "City", "State", "Country", "Name", "Employees"]
data_csv.drop(data_csv.columns[2], 1)
# Out:
#   ID          Address             State Country         Name Employees
# 1  1     3666 21st St          CA 94114     USA      Madeira         8
# 2  2   735 Dolores St          CA 94119     USA  Bready Shop        15
# 3  3      332 Hill St  California 94114     USA  Super River        25
# 4  4     3995 23rd St          CA 94114     USA   Ben's Shop        10
# 5  5  1056 Sanchez St        California     USA      Sanchez        12
# 6  6  551 Alvarado St          CA 94114     USA   Richvalley        20

# %%
# the loc object accepts integer based indices for rows and columns when they don't have labels.
# [] accessing for one more columns by name or only for slicing rows  by index only
# [[]] returns a dataframe while [] returns an object.it is used to get one or more rows or one or more columns together. loc[x,y] or iloc[x,y] returns the cell text as a string
# [[]] are not used while slicing of rows and columns in loc or iloc
# For dropping rows can't be dropped with labels with either drop() or index[]. Columns can be dropped with labels only with drop().
